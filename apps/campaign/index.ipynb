# %% [markdown]
# # AICR Campaign Dashboard
#
# Public campaign artifact coverage and provenance links.

# %%
from apps.campaign.components import build_dashboard
from lib.manifest import load_manifest, validate_manifest

manifest = load_manifest('data/manifests/manifest.sample.json')
validate_manifest(manifest)
dashboard = build_dashboard(manifest)
dashboard.servable(title='AICR Campaign Dashboard')
dashboard
