# %% [markdown]
# # DataLoader Study Artifacts

# %%
from apps.studies.components import build_module_dashboard
from lib.manifest import load_dashboard_manifest

load_result = load_dashboard_manifest(default_remote_url='')
dashboard = build_module_dashboard(load_result.manifest, 'dataloader')
dashboard.servable()
dashboard
