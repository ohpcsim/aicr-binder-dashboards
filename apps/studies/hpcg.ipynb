# %% [markdown]
# # HPCG Study Artifacts
#
# HPCG entries remain planned or diagnostic until AICR-owned rows have complete artifacts.

# %%
from apps.studies.components import build_module_dashboard
from lib.manifest import load_manifest, validate_manifest

manifest = load_manifest('data/manifests/manifest.sample.json')
validate_manifest(manifest)
dashboard = build_module_dashboard(manifest, 'hpcg')
dashboard.servable()
