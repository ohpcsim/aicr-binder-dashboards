# %% [markdown]
# # AICR Study Dashboard
#
# Module study artifacts, provenance links, and evidence filters.

# %%
from apps.studies.components import build_dashboard
from lib.manifest import load_dashboard_manifest

load_result = load_dashboard_manifest(default_remote_url='')
dashboard = build_dashboard(load_result.manifest, load_result)
dashboard.servable(title='AICR Study Dashboard')
dashboard
